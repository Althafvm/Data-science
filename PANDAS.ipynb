# %% [markdown]
# <a href="https://colab.research.google.com/github/Althafvm/Data-science/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[20,30,40,90]
s=pd.Series(data,index=['A','B','C','D'])
print(s)
# Out:
# A    20
# B    30
# C    40
# D    90
# dtype: int64

# %%
import pandas as pd
data=[20,30,40,90]
s=pd.Series(data)
print(s)
# Out:
# 0    20
# 1    30
# 2    40
# 3    90
# dtype: int64

# %%
data={'name':'devika','age':50}
s=pd.Series(data)
print(s)
# Out:
# name    devika
# age         50
# dtype: object

# %%
data=[20,30,40,50]
s=pd.Series(data)
print(s.loc[1])
# Out:
# 30

# %%
data=[20,30,40,50]
s=pd.Series(data,index=['A','B','C','D'])
print(s.loc['A'])
print(s.iloc[0])
# Out:
# 20
# 20

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
a=s[s>30]
print(a)
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# B    40
# C    66
# D    70
# dtype: int64
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
a=s[s<30]
print(a)
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# A    22
# dtype: int64
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
a=s[s!=30]
print(a)
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# A    22
# B    40
# C    66
# D    70
# dtype: int64
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.nunique())
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# 5

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
print(ar.nunique())
print(ar.value_counts())
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]
# 5
# 20    2
# 30    2
# 60    2
# 50    1
# 80    1
# Name: count, dtype: int64

# %%
data=[20,30,None,None,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.isnull)
print(ar.notnull)
# Out:
# 0    20.0
# 1    30.0
# 2     NaN
# 3     NaN
# 4    60.0
# 5    60.0
# 6    80.0
# dtype: float64
# <bound method Series.isnull of 0    20.0
# 1    30.0
# 2     NaN
# 3     NaN
# 4    60.0
# 5    60.0
# 6    80.0
# dtype: float64>
# <bound method Series.notnull of 0    20.0
# 1    30.0
# 2     NaN
# 3     NaN
# 4    60.0
# 5    60.0
# 6    80.0
# dtype: float64>
