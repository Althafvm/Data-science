# %% [markdown]
# <a href="https://colab.research.google.com/github/Althafvm/Data-science/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=[20,30,40,90]
s=pd.Series(data,index=['A','B','C','D'])
print(s)
# Out:
# A    20
# B    30
# C    40
# D    90
# dtype: int64

# %%
import pandas as pd
data=[20,30,40,90]
s=pd.Series(data)
print(s)
# Out:
# 0    20
# 1    30
# 2    40
# 3    90
# dtype: int64

# %%
data={'name':'devika','age':50}
s=pd.Series(data)
print(s)
# Out:
# name    devika
# age         50
# dtype: object

# %%
data=[20,30,40,50]
s=pd.Series(data)
print(s.loc[1])
# Out:
# 30

# %%
data=[20,30,40,50]
s=pd.Series(data,index=['A','B','C','D'])
print(s.loc['A'])
print(s.iloc[0])
# Out:
# 20
# 20

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
a=s[s>30]
print(a)
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# B    40
# C    66
# D    70
# dtype: int64
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
a=s[s<30]
print(a)
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# A    22
# dtype: int64
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
data=[22,40,66,70]
s=pd.Series(data,index=['A','B','C','D'])
a=s[s!=30]
print(a)
print(s.loc['A':'B'])
print(s.iloc[:2])
# Out:
# A    22
# B    40
# C    66
# D    70
# dtype: int64
# A    22
# B    40
# dtype: int64
# A    22
# B    40
# dtype: int64

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.nunique())
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# 5

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
print(ar.nunique())
print(ar.value_counts())
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]
# 5
# 20    2
# 30    2
# 60    2
# 50    1
# 80    1
# Name: count, dtype: int64

# %%
data=[20,30,None,None,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.isnull)
print(ar.notnull)
# Out:
# 0    20.0
# 1    30.0
# 2     NaN
# 3     NaN
# 4    60.0
# 5    60.0
# 6    80.0
# dtype: float64
# <bound method Series.isnull of 0    20.0
# 1    30.0
# 2     NaN
# 3     NaN
# 4    60.0
# 5    60.0
# 6    80.0
# dtype: float64>
# <bound method Series.notnull of 0    20.0
# 1    30.0
# 2     NaN
# 3     NaN
# 4    60.0
# 5    60.0
# 6    80.0
# dtype: float64>

# %%
import pandas as pd
import numpy as np
data={"name":["alice","bob","charlie","david","emma"],"age":[20,21,19,22,20],"marks":[85,72,np.nan,90,65],"attendance":[95,80,75,np.nan,88],"city":["kochi","delhi","munbai","kochi","chennai"]}
df=pd.DataFrame(data)
print("original dataframe")
print(df)
# Out:
# original dataframe
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
import pandas as pd
import numpy as np
data={"name":["alice","bob","charlie","david","emma"],"age":[20,21,19,22,20],"marks":[85,72,np.nan,90,65],"attendance":[95,80,75,np.nan,88],"city":["kochi","delhi","munbai","kochi","chennai"]}
df=pd.DataFrame(data)
print("original dataframe")
print(df)
print("\nFirst 3 rows:")
print(df.head(2))

print("\nFirst 2 rows:")
print(df.tail(3))
# Out:
# original dataframe
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# First 3 rows:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 1    bob   21   72.0        80.0  delhi
#
# First 2 rows:
#       name  age  marks  attendance     city
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
import pandas as pd
import numpy as np
data={"name":["alice","bob","charlie","david","emma"],"age":[20,21,19,22,20],"marks":[85,72,np.nan,90,65],"attendance":[95,80,75,np.nan,88],"city":["kochi","delhi","munbai","kochi","chennai"]}
df=pd.DataFrame(data)
print("original dataframe")
print(df)
print("\nFirst 3 rows:")
print(df.head(2))

print("\nFirst 2 rows:")
print(df.tail(3))

print("\nDataFrame shapes")
print(df.shape)
# Out:
# original dataframe
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# First 3 rows:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 1    bob   21   72.0        80.0  delhi
#
# First 2 rows:
#       name  age  marks  attendance     city
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# DataFrame shapes
# (5, 5)

# %%
import pandas as pd
import numpy as np
data={"name":["alice","bob","charlie","david","emma"],"age":[20,21,19,22,20],"marks":[85,72,np.nan,90,65],"attendance":[95,80,75,np.nan,88],"city":["kochi","delhi","munbai","kochi","chennai"]}
df=pd.DataFrame(data)
print("original dataframe")
print(df)
print("\nFirst 3 rows:")
print(df.head(2))

print("\nFirst 2 rows:")
print(df.tail(3))

print("\nDataFrame shape")
print(df.shape)

print("\nDataFrame columns")
print(df.columns)
# Out:
# original dataframe
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# First 3 rows:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 1    bob   21   72.0        80.0  delhi
#
# First 2 rows:
#       name  age  marks  attendance     city
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# DataFrame shape
# (5, 5)
#
# DataFrame colums
# Index(['name', 'age', 'marks', 'attendance', 'city'], dtype='object')

# %%
import pandas as pd
import numpy as np
data={"name":["alice","bob","charlie","david","emma"],"age":[20,21,19,22,20],"marks":[85,72,np.nan,90,65],"attendance":[95,80,75,np.nan,88],"city":["kochi","delhi","munbai","kochi","chennai"]}
df=pd.DataFrame(data)
print("original dataframe")
print(df)
print("\nFirst 3 rows:")
print(df.head(2))

print("\nFirst 2 rows:")
print(df.tail(3))

print("\nDataFrame shape")
print(df.shape)

print("\ncolumns name")
print(df.columns)

print("\ndatatype name")
print(df.dtypes)
# Out:
# original dataframe
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# First 3 rows:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 1    bob   21   72.0        80.0  delhi
#
# First 2 rows:
#       name  age  marks  attendance     city
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# DataFrame shape
# (5, 5)
#
# columns name
# Index(['name', 'age', 'marks', 'attendance', 'city'], dtype='object')
#
# datatype name
# name           object
# age             int64
# marks         float64
# attendance    float64
# city           object
# dtype: object

# %%
import pandas as pd
import numpy as np
data={"name":["alice","bob","charlie","david","emma"],"age":[20,21,19,22,20],"marks":[85,72,np.nan,90,65],"attendance":[95,80,75,np.nan,88],"city":["kochi","delhi","munbai","kochi","chennai"]}
df=pd.DataFrame(data)
print("original dataframe")
print(df)
print("\nFirst 3 rows:")
print(df.head(2))

print("\nFirst 2 rows:")
print(df.tail(3))

print("\nDataFrame shape")
print(df.shape)

print("\ncolumns name")
print(df.columns)

print("\ndatatype name")
print(df.dtypes)

print("\nmarks columns")
print(df.marks)

print("\nname and marks")
print(df[["name","marks"]])

print("\nfrist 3 rows")
print(df.iloc[0:3])

print("\nrow 1 to 3, name and marks:")
print(df.loc[1:3,["name","marks"]])

print("\nrow 1 to 3, name,marks,age,city and attendance:")
print(df.loc[1:3,["name","marks","age","city","attendance"]])

print("\nstudent with marks greater than 75:")
print(df[df["marks"]>75])

print("\nstudent from kochi:")
print(df[df["city"]== "kochi"])

print("\nstudent with marks>70 AND attendance>80:")
print(df[
    (df["marks"]>70) &
    (df["attendance"]>80)
    ])
print("\nmarks +5:")
print(df["marks"]+5)

print("\nmarks *2:")
print(df["marks"]*2)

print("\naverage marks:")
print(df["marks"].mean())

print("\nmaximum marks:")
print(df["marks"].max())

print("\nminimum marks:")
print(df["marks"].min())

print("\ntotal marks:")
print(df["marks"].sum())

print("\nsorted by marks:")
print(df.sort_values("marks"))

print("\nsorted by marks - highest frist:")
print(df.sort_values("marks",ascending=False))
# Out:
# original dataframe
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# First 3 rows:
#     name  age  marks  attendance   city
# 0  alice   20   85.0        95.0  kochi
# 1    bob   21   72.0        80.0  delhi
#
# First 2 rows:
#       name  age  marks  attendance     city
# 2  charlie   19    NaN        75.0   munbai
# 3    david   22   90.0         NaN    kochi
# 4     emma   20   65.0        88.0  chennai
#
# DataFrame shape
# (5, 5)
#
# columns name
# Index(['name', 'age', 'marks', 'attendance', 'city'], dtype='object')
#
# datatype name
# name           object
# age             int64
# marks         float64
# attendance    float64
# city           object
# dtype: object
#
# marks columns
# 0    85.0
# 1    72.0
# 2     NaN
# 3    90.0
# 4    65.0
# ...

# %%
df_renamed =df.rename(
    columns={
        "marks":"score",
        "attendance":"attendance_percentage"
    }
)
print("\nrenamed dataframe:")
print(df_renamed)
# Out:
# renamed dataframe:
#       name  age  score  attendance_percentage     city
# 0    alice   20   85.0                   95.0    kochi
# 1      bob   21   72.0                   80.0    delhi
# 2  charlie   19    NaN                   75.0   munbai
# 3    david   22   90.0                    NaN    kochi
# 4     emma   20   65.0                   88.0  chennai

# %%
print("\nmissing values:")
print(df.isna())

print("\nnumber of missing values:")
print(df.isna().sum())
# Out:
# missing values:
#     name    age  marks  attendance   city
# 0  False  False  False       False  False
# 1  False  False  False       False  False
# 2  False  False   True       False  False
# 3  False  False  False        True  False
# 4  False  False  False       False  False
#
# number of missing values:
# name          0
# age           0
# marks         1
# attendance    1
# city          0
# dtype: int64

# %%
#forward fill
df_forward =df.copy()
df_forward = df_forward.ffill()
print("\nforward fill:")
print(df_forward)
# Out:
# forward fill:
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19   72.0        75.0   munbai
# 3    david   22   90.0        75.0    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
#backward fill
df_backward =df.copy()
df_backward = df_backward.bfill()
print("\nbackward fill:")
print(df_backward)
# Out:
# backward fill:
#       name  age  marks  attendance     city
# 0    alice   20   85.0        95.0    kochi
# 1      bob   21   72.0        80.0    delhi
# 2  charlie   19   90.0        75.0   munbai
# 3    david   22   90.0        88.0    kochi
# 4     emma   20   65.0        88.0  chennai

# %%
import pandas as pd
df=pd.read_csv("/content/nigeria_messy_sales_dataset.csv")
df
# Out:
#           Customer Name    State     Product  Units Sold  Unit Price  \
# 0                   NaN   rivers    KEYBOARD         NaN         NaN
# 1          Allison Hill    Lagos  Headphones         NaN   267992.94
# 2           Noah Rhodes  Anambra    Keyboard         NaN    42364.41
# 3       Angie Henderson    Delta    Keyboard         NaN   279444.94
# 4         Daniel Wagner    Delta      Tablet         NaN    95899.74
# ..                  ...      ...         ...         ...         ...
# 545    Zachary Mitchell    Ekiti     Monitor         6.0    23989.09
# 546                 NaN  Katsina      Tablet         NaN   223764.24
# 547  Katherine Martinez   Bauchi       Phone         NaN   104084.92
# 548          Jodi Roach    Niger     Charger         NaN    29756.89
# 549     Brandon Fleming      imo      Camera         NaN    70027.13
#
#      Total Sale   Sale Date Sales Channel  \
# 0           NaN  2025-04-27        Online
# 1           NaN  2024-03-15     Wholesale
# ...

# %%
#1
print(df.shape)
# Out:
# (550, 9)

# %%
#2
print(df.head(7))
print(df.tail(5))
# Out:
#      Customer Name    State     Product  Units Sold  Unit Price  Total Sale  \
# 0              NaN   rivers    KEYBOARD         NaN         NaN         NaN
# 1     Allison Hill    Lagos  Headphones         NaN   267992.94         NaN
# 2      Noah Rhodes  Anambra    Keyboard         NaN    42364.41         NaN
# 3  Angie Henderson    Delta    Keyboard         NaN   279444.94         NaN
# 4    Daniel Wagner    Delta      Tablet         NaN    95899.74         NaN
# 5  Cristian Santos      Oyo      Camera         NaN   118189.90         NaN
# 6  Connie Lawrence   Rivers      Tablet        36.0   185141.90   6665108.4
#
#     Sale Date Sales Channel                              Order ID
# 0  2025-04-27        Online                                   NaN
# 1  2024-03-15     Wholesale  4c636e95-025f-4543-8997-623ae0723d96
# 2  2024-12-10           NaN  edaf3766-1b78-4ede-9a4f-fc0c9165f2ed
# 3  2024-04-05           NaN  74503887-48d9-4846-95c5-51fcfba57cc8
# ...

# %%
#3
print(df[["Product","Units Sold","Unit Price","Total Sale"]])
# Out:
#         Product  Units Sold  Unit Price  Total Sale
# 0      KEYBOARD         NaN         NaN         NaN
# 1    Headphones         NaN   267992.94         NaN
# 2      Keyboard         NaN    42364.41         NaN
# 3      Keyboard         NaN   279444.94         NaN
# 4        Tablet         NaN    95899.74         NaN
# ..          ...         ...         ...         ...
# 545     Monitor         6.0    23989.09   143934.54
# 546      Tablet         NaN   223764.24         NaN
# 547       Phone         NaN   104084.92         NaN
# 548     Charger         NaN    29756.89         NaN
# 549      Camera         NaN    70027.13         NaN
#
# [550 rows x 4 columns]

# %%
#4
print(df[(df["Units Sold"]>50)])
# Out:
#             Customer Name        State     Product  Units Sold  Unit Price  \
# 19           Derek Zuniga          Imo  Headphones        77.0    92649.51
# 31          Zachary Hicks      Anambra      Camera        68.0    15880.87
# 32      Anthony Rodriguez          Oyo     MONITOR        96.0   144394.41
# 37         Debra Davidson        Benue       Phone        65.0   246587.56
# 38         Jeffrey Chavez       Rivers     Charger        79.0    73037.87
# ..                    ...          ...         ...         ...         ...
# 515       Julie Dominguez  Cross River     Monitor        59.0   270431.25
# 522         Howard Norman        benue      Camera        69.0    84471.72
# 528      Samantha Gardner       Rivers  HEADPHONES        52.0    62543.86
# 541         Phillip Berry       Bauchi  Headphones        97.0   115461.94
# 544  Mr. Justin Green III       Sokoto    KEYBOARD        65.0   206948.51
#
#       Total Sale   Sale Date Sales Channel  \
# ...

# %%
#5
print(df[(df["Unit Price"]>100000)])
# Out:
#             Customer Name    State     Product  Units Sold  Unit Price  \
# 1            Allison Hill    Lagos  Headphones         NaN   267992.94
# 3         Angie Henderson    Delta    Keyboard         NaN   279444.94
# 5         Cristian Santos      Oyo      Camera         NaN   118189.90
# 6         Connie Lawrence   Rivers      Tablet        36.0   185141.90
# 7         Abigail Shaffer      Imo    Keyboard         NaN   252859.28
# ..                    ...      ...         ...         ...         ...
# 542        Jennifer Banks      Imo     Monitor         NaN   222053.68
# 543      Brian Fitzgerald  Katsina      Laptop         NaN   237254.18
# 544  Mr. Justin Green III   Sokoto    KEYBOARD        65.0   206948.51
# 546                   NaN  Katsina      Tablet         NaN   223764.24
# 547    Katherine Martinez   Bauchi       Phone         NaN   104084.92
#
#       Total Sale   Sale Date Sales Channel  \
# 1            NaN  2024-03-15     Wholesale
# ...

# %%
#6
print(df[df["Sales Channel"]=="Online"])
# Out:
#             Customer Name   State     Product  Units Sold  Unit Price  \
# 0                     NaN  rivers    KEYBOARD         NaN         NaN
# 7         Abigail Shaffer     Imo    Keyboard         NaN   252859.28
# 19           Derek Zuniga     Imo  Headphones        77.0    92649.51
# 23            Patty Perez   Delta      Camera         NaN   188963.51
# 24            Ethan Adams   Ekiti      LAPTOP         4.0   179274.43
# ..                    ...     ...         ...         ...         ...
# 525       Jasmine Beltran   Delta      Tablet         NaN    54216.67
# 534         William Gould   Abuja      Laptop         NaN    90133.43
# 538        Austin Osborne   Ekiti    Keyboard         NaN   203271.97
# 542        Jennifer Banks     Imo     Monitor         NaN   222053.68
# 544  Mr. Justin Green III  Sokoto    KEYBOARD        65.0   206948.51
#
#       Total Sale   Sale Date Sales Channel  \
# 0            NaN  2025-04-27        Online
# ...

# %%
#7
print(df["State"].unique())
print(df["State"].nunique())
# Out:
# ['rivers' 'Lagos' 'Anambra' 'Delta' 'Oyo' 'Rivers' 'Imo' 'Kano' 'plateau'
#  'Niger' 'Abuja' 'Enugu' 'Bauchi' 'Katsina' 'lagos' 'Ekiti' 'Plateau'
#  'Kaduna' 'Sokoto' 'kano' 'Benue' 'Osun' 'imo' 'Borno' 'enugu' 'anambra'
#  'katsina' 'delta' 'Cross River' 'oyo' 'osun' 'kaduna' 'niger' 'borno'
#  'abuja' 'bauchi' 'cross river' 'ekiti' 'sokoto' 'benue']
# 40

# %%
#8
print(df["Sales Channel"].value_counts())
# Out:
# Sales Channel
# Direct       124
# Wholesale    111
# Retail       108
# Online       101
# Name: count, dtype: int64

# %%
#9
print(df.isnull())
# Out:
#      Customer Name  State  Product  Units Sold  Unit Price  Total Sale  \
# 0             True  False    False        True        True        True
# 1            False  False    False        True       False        True
# 2            False  False    False        True       False        True
# 3            False  False    False        True       False        True
# 4            False  False    False        True       False        True
# ..             ...    ...      ...         ...         ...         ...
# 545          False  False    False       False       False       False
# 546           True  False    False        True       False        True
# 547          False  False    False        True       False        True
# 548          False  False    False        True       False        True
# 549          False  False    False        True       False        True
#
#      Sale Date  Sales Channel  Order ID
# 0        False          False      True
# ...

# %%
#10
print(df.dropna())
# Out:
#             Customer Name   State     Product  Units Sold  Unit Price  \
# 6         Connie Lawrence  Rivers      Tablet        36.0   185141.90
# 11         Monica Herrera   Abuja      Laptop         3.0   153159.37
# 12           Jamie Arnold   Lagos      Tablet        43.0   147209.07
# 18             Holly Wood   lagos  Headphones        43.0   125253.81
# 19           Derek Zuniga     Imo  Headphones        77.0    92649.51
# ..                    ...     ...         ...         ...         ...
# 517         Judith Carter    Kano      Laptop        46.0   170251.85
# 527         Monica Miller   Lagos      Laptop        47.0     5189.60
# 537   Lawrence Harrington  Rivers     Monitor        16.0   254908.01
# 544  Mr. Justin Green III  Sokoto    KEYBOARD        65.0   206948.51
# 545      Zachary Mitchell   Ekiti     Monitor         6.0    23989.09
#
#       Total Sale   Sale Date Sales Channel  \
# 6     6665108.40  2024-09-10     Wholesale
# ...
